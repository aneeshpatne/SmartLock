# %%
import qrcode

# %%
img = qrcode.make('Aneesh')

# %%
type(img)
# Out:
# qrcode.image.pil.PilImage

# %%
img.show()
# Out:
# <PIL.Image.Image image mode=1 size=290x290>

# %%
import time

for i in range(10):
    current_time  = (time.strftime('%H:%M:%S'))
    h, m, s = map(int, current_time.split(':'))
    img = qrcode.make(str(h + m + s))
    img.show()
    time.sleep(2)
# Out:
# <PIL.Image.Image image mode=1 size=290x290>
# <PIL.Image.Image image mode=1 size=290x290>
# <PIL.Image.Image image mode=1 size=290x290>
# <PIL.Image.Image image mode=1 size=290x290>
# <PIL.Image.Image image mode=1 size=290x290>
# <PIL.Image.Image image mode=1 size=290x290>
# <PIL.Image.Image image mode=1 size=290x290>
# <PIL.Image.Image image mode=1 size=290x290>
# <PIL.Image.Image image mode=1 size=290x290>
# <PIL.Image.Image image mode=1 size=290x290>
